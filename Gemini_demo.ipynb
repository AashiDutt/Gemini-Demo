# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 1.3 MB/s eta 0:00:00

# %%
from google.colab import userdata
import google.generativeai as genai
from PIL import Image

# %%
API_KEY = userdata.get('gemini')

# Configure the API key.
genai.configure(api_key=API_KEY)

# %%
# List all available models.
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# #### Gemini Pro 1.0 (Text input)

# %%
# Configure the model.
model = genai.GenerativeModel(model_name='gemini-pro')
prompt = "Suggest some best places to visit in India."
# Give the input image and prompt, get response.

response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# **Historical Landmarks:**
#
# * **Taj Mahal, Agra:** An iconic mausoleum renowned for its architectural beauty and historical significance.
# * **Red Fort, Delhi:** A vast and imposing fort that was the seat of power for the Mughal Empire.
# * **Hawa Mahal, Jaipur:** A magnificent sandstone palace famous for its intricate facade with 953 windows.
# * **Golden Temple, Amritsar:** A Sikh pilgrimage site with a stunning gold-covered dome.
# * **Ajanta and Ellora Caves, Maharashtra:** Ancient Buddhist and Jain cave temples with intricate sculptures and paintings.
#
# **Natural Wonders:**
#
# * **Ladakh:** A high-altitude desert region offering breathtaking mountain scenery, pristine lakes, and adventure activities.
# * **Kerala Backwaters:** A serene network of interconnected waterways, palm-fringed canals, and lush greenery.
# * **Sundarbans National Park:** The world's largest mangrove forest, home to the endangered Royal Bengal Tiger.
# * **Himachal Pradesh:** A picturesque state with snow-capped peaks, serene hill stations, and scenic trekking trails.
# * **Kaziranga National Park, Assam:** A UNESCO World Heritage site known for its large population of one-horned rhinoceros.
#
# **Cultural and Spiritual Sites:**
#
# * **Varanasi:** A sacred city on the banks of the Ganges River, renowned for its religious significance and vibrant atmosphere.
# * **Pushkar:** A town known for its holy lake and the annual Pushkar Fair, one of the largest camel fairs in Asia.
# * **Konark Sun Temple, Odisha:** An architectural marvel dedicated to the sun god, adorned with intricate carvings.
# * **Somnath Temple, Gujarat:** One of the twelve Jyotirlinga shrines, considered sacred by Hindus.
# * **Bodh Gaya:** A Buddhist pilgrimage site where Buddha attained enlightenment.
#
# **Urban Destinations:**
#
# * **Mumbai (Bombay):** India's financial and entertainment capital, known for its iconic Gateway of India and Bollywood film industry.
# * **Delhi:** The political and historical heart of India, home to numerous museums, monuments, and vibrant markets.
# * **Kolkata (Calcutta):** A cultural hub with a rich history, renowned for its intellectual and artistic heritage.
# * **Bengaluru (Bangalore):** India's technology hub, known for its modern skyscrapers and vibrant nightlife.
# * **Hyderabad:** A historic city with a unique blend of Indian and Islamic architecture, famous for its biryani.

# %%
print(response.prompt_feedback)
# Out:
# safety_ratings {
#   category: HARM_CATEGORY_SEXUALLY_EXPLICIT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HATE_SPEECH
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_HARASSMENT
#   probability: NEGLIGIBLE
# }
# safety_ratings {
#   category: HARM_CATEGORY_DANGEROUS_CONTENT
#   probability: NEGLIGIBLE
# }

# %% [markdown]
# #### Gemini Pro Vision 1.0 (Text + image input)

# %%
# Configure the model.
model = genai.GenerativeModel(model_name='gemini-pro-vision')

# Load the image.
img = Image.open('/content/img.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=826x508>

# %%
prompt = "Identify the place from the image."

# Give the input image and prompt, get response.
response = model.generate_content([prompt, img], stream=True)
response.resolve()

print(response.text)
# Out:
#  Pangong Tso, or Pangong Lake, is an endorheic lake in the Himalayas situated at a height of almost 4,350 m (14,270 ft). It is the world's highest saltwater lake.
